# %%
# !pip install tflite-model-maker
# Out:
# Requirement already satisfied: tflite-model-maker in c:\hi_course\python_file\lib\site-packages (0.3.4)
# Requirement already satisfied: tensorflowjs>=2.4.0 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (3.18.0)
# Requirement already satisfied: tf-models-official==2.3.0 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (2.3.0)
# Requirement already satisfied: librosa==0.8.1 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (0.8.1)
# Requirement already satisfied: absl-py>=0.10.0 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tflite-model-maker) (0.15.0)
# Requirement already satisfied: flatbuffers==1.12 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (1.12)
# Requirement already satisfied: six>=1.12.0 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tflite-model-maker) (1.15.0)
# Requirement already satisfied: pillow>=7.0.0 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (9.4.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tflite-model-maker) (1.19.5)
# Requirement already satisfied: numba==0.53 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (0.53.0)
# Requirement already satisfied: tensorflow>=2.6.0 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tflite-model-maker) (2.7.4)
# Requirement already satisfied: tensorflow-model-optimization>=0.5 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (0.7.3)
# Requirement already satisfied: matplotlib<3.5.0,>=3.0.3 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (3.4.3)
# Requirement already satisfied: neural-structured-learning>=1.3.1 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (1.4.0)
# Requirement already satisfied: Cython>=0.29.13 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (0.29.33)
# Requirement already satisfied: tensorflow-datasets>=2.1.0 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (4.8.2)
# Requirement already satisfied: lxml>=4.6.1 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (4.9.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (1.25.11)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (0.12.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (6.0)
# Requirement already satisfied: tensorflow-addons>=0.11.2 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (0.19.0)
# Requirement already satisfied: sentencepiece>=0.1.91 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (0.1.97)
# Requirement already satisfied: tflite-support>=0.3.1 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tflite-model-maker) (0.3.1)
# Requirement already satisfied: fire>=0.3.1 in c:\hi_course\python_file\lib\site-packages (from tflite-model-maker) (0.5.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\hi_course\python_file\lib\site-packages (from librosa==0.8.1->tflite-model-maker) (1.10.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\hi_course\python_file\lib\site-packages (from librosa==0.8.1->tflite-model-maker) (1.2.0)
# Requirement already satisfied: decorator>=3.0.0 in c:\hi_course\python_file\lib\site-packages (from librosa==0.8.1->tflite-model-maker) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\hi_course\python_file\lib\site-packages (from librosa==0.8.1->tflite-model-maker) (20.9)
# Requirement already satisfied: joblib>=0.14 in c:\hi_course\python_file\lib\site-packages (from librosa==0.8.1->tflite-model-maker) (1.2.0)
# Requirement already satisfied: audioread>=2.0.0 in c:\hi_course\python_file\lib\site-packages (from librosa==0.8.1->tflite-model-maker) (3.0.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\hi_course\python_file\lib\site-packages (from librosa==0.8.1->tflite-model-maker) (0.4.2)
# Requirement already satisfied: soundfile>=0.10.2 in c:\hi_course\python_file\lib\site-packages (from librosa==0.8.1->tflite-model-maker) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\hi_course\python_file\lib\site-packages (from librosa==0.8.1->tflite-model-maker) (1.6.0)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\hi_course\python_file\lib\site-packages (from numba==0.53->tflite-model-maker) (0.36.0)
# Requirement already satisfied: setuptools in c:\hi_course\python_file\lib\site-packages (from numba==0.53->tflite-model-maker) (56.0.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in c:\hi_course\python_file\lib\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (2.79.0)
# Requirement already satisfied: gin-config in c:\hi_course\python_file\lib\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (0.5.0)
# Requirement already satisfied: google-cloud-bigquery>=0.31.0 in c:\hi_course\python_file\lib\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (3.6.0)
# Requirement already satisfied: tf-slim>=1.1.0 in c:\hi_course\python_file\lib\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (1.1.0)
# Requirement already satisfied: psutil>=5.4.3 in c:\hi_course\python_file\lib\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (5.9.4)
# Requirement already satisfied: opencv-python-headless in c:\hi_course\python_file\lib\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (4.7.0.72)
# Requirement already satisfied: pandas>=0.22.0 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (1.4.4)
# Requirement already satisfied: dataclasses in c:\hi_course\python_file\lib\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (0.6)
# Requirement already satisfied: kaggle>=1.3.9 in c:\hi_course\python_file\lib\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (1.5.12)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in c:\hi_course\python_file\lib\site-packages (from tf-models-official==2.3.0->tflite-model-maker) (9.0.0)
# Requirement already satisfied: termcolor in c:\users\deepa\appdata\roaming\python\python39\site-packages (from fire>=0.3.1->tflite-model-maker) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\hi_course\python_file\lib\site-packages (from matplotlib<3.5.0,>=3.0.3->tflite-model-maker) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\hi_course\python_file\lib\site-packages (from matplotlib<3.5.0,>=3.0.3->tflite-model-maker) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\hi_course\python_file\lib\site-packages (from matplotlib<3.5.0,>=3.0.3->tflite-model-maker) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\hi_course\python_file\lib\site-packages (from matplotlib<3.5.0,>=3.0.3->tflite-model-maker) (1.4.4)
# Requirement already satisfied: attrs in c:\hi_course\python_file\lib\site-packages (from neural-structured-learning>=1.3.1->tflite-model-maker) (22.2.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (15.0.6.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (2.7.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (1.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (0.30.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (0.38.4)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (3.7.4.3)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (1.6.3)
# Requirement already satisfied: tensorboard~=2.6 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (2.9.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\hi_course\python_file\lib\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (1.51.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\deepa\appdata\roaming\python\python39\site-packages (from tensorflow>=2.6.0->tflite-model-maker) (3.1.0)
# Requirement already satisfied: typeguard>=2.7 in c:\hi_course\python_file\lib\site-packages (from tensorflow-addons>=0.11.2->tflite-model-maker) (2.13.3)
# Requirement already satisfied: promise in c:\hi_course\python_file\lib\site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (2.3)
# Requirement already satisfied: dm-tree in c:\hi_course\python_file\lib\site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (0.1.8)
# Requirement already satisfied: dill in c:\hi_course\python_file\lib\site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (0.3.6)
# Requirement already satisfied: tensorflow-metadata in c:\hi_course\python_file\lib\site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (1.12.0)
# Requirement already satisfied: toml in c:\hi_course\python_file\lib\site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (0.10.2)
# Requirement already satisfied: tqdm in c:\hi_course\python_file\lib\site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (4.64.1)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in c:\hi_course\python_file\lib\site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (1.0.0)
# Requirement already satisfied: requests>=2.19.0 in c:\hi_course\python_file\lib\site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (2.28.2)
# Requirement already satisfied: click in c:\hi_course\python_file\lib\site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (8.1.3)
# Requirement already satisfied: pybind11>=2.6.0 in c:\hi_course\python_file\lib\site-packages (from tflite-support>=0.3.1->tflite-model-maker) (2.10.3)
# Requirement already satisfied: zipp in c:\hi_course\python_file\lib\site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets>=2.1.0->tflite-model-maker) (3.12.0)
# Requirement already satisfied: importlib_resources in c:\hi_course\python_file\lib\site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets>=2.1.0->tflite-model-maker) (5.12.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\hi_course\python_file\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (2.16.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\hi_course\python_file\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (4.1.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\hi_course\python_file\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (0.21.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\hi_course\python_file\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\hi_course\python_file\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (2.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.15.0 in c:\hi_course\python_file\lib\site-packages (from google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker) (1.22.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in c:\hi_course\python_file\lib\site-packages (from google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker) (2.3.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in c:\hi_course\python_file\lib\site-packages (from google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker) (2.4.1)
# Requirement already satisfied: certifi in c:\hi_course\python_file\lib\site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (2022.12.7)
# Requirement already satisfied: python-slugify in c:\hi_course\python_file\lib\site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (8.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\hi_course\python_file\lib\site-packages (from pandas>=0.22.0->tf-models-official==2.3.0->tflite-model-maker) (2022.7.1)
# Requirement already satisfied: appdirs>=1.3.0 in c:\hi_course\python_file\lib\site-packages (from pooch>=1.0->librosa==0.8.1->tflite-model-maker) (1.4.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\hi_course\python_file\lib\site-packages (from requests>=2.19.0->tensorflow-datasets>=2.1.0->tflite-model-maker) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\hi_course\python_file\lib\site-packages (from requests>=2.19.0->tensorflow-datasets>=2.1.0->tflite-model-maker) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\hi_course\python_file\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.1->tflite-model-maker) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\hi_course\python_file\lib\site-packages (from soundfile>=0.10.2->librosa==0.8.1->tflite-model-maker) (1.15.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\hi_course\python_file\lib\site-packages (from tensorboard~=2.6->tensorflow>=2.6.0->tflite-model-maker) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\hi_course\python_file\lib\site-packages (from tensorboard~=2.6->tensorflow>=2.6.0->tflite-model-maker) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\hi_course\python_file\lib\site-packages (from tensorboard~=2.6->tensorflow>=2.6.0->tflite-model-maker) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\hi_course\python_file\lib\site-packages (from tensorboard~=2.6->tensorflow>=2.6.0->tflite-model-maker) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\hi_course\python_file\lib\site-packages (from tensorboard~=2.6->tensorflow>=2.6.0->tflite-model-maker) (0.4.6)
# Requirement already satisfied: colorama in c:\hi_course\python_file\lib\site-packages (from click->tensorflow-datasets>=2.1.0->tflite-model-maker) (0.4.6)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in c:\hi_course\python_file\lib\site-packages (from tensorflow-metadata->tensorflow-datasets>=2.1.0->tflite-model-maker) (1.58.0)
# Requirement already satisfied: pycparser in c:\hi_course\python_file\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.8.1->tflite-model-maker) (2.21)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in c:\hi_course\python_file\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\hi_course\python_file\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\hi_course\python_file\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\hi_course\python_file\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\hi_course\python_file\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.6.0->tflite-model-maker) (1.3.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\hi_course\python_file\lib\site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker) (1.5.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\hi_course\python_file\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.6.0->tflite-model-maker) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\hi_course\python_file\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.6->tensorflow>=2.6.0->tflite-model-maker) (2.1.2)
# Requirement already satisfied: text-unidecode>=1.3 in c:\hi_course\python_file\lib\site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\hi_course\python_file\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\hi_course\python_file\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.6.0->tflite-model-maker) (3.2.2)

# %%
import tensorflow as tf
import tflite_model_maker as mm
from tflite_model_maker import audio_classifier
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import itertools
import glob
import random

from IPython.display import Audio, Image
from scipy.io import wavfile

print(f"TensorFlow Version: {tf.__version__}")
print(f"Model Maker Version: {mm.__version__}")

birds_dataset_folder = tf.keras.utils.get_file('birds_dataset.zip',
                                                'https://storage.googleapis.com/laurencemoroney-blog.appspot.com/birds_dataset.zip',
                                                cache_dir='./',
                                                cache_subdir='dataset',
                                                extract=True)


# @title [Run this] Util functions and data structures.

data_dir = './dataset/small_birds_dataset'

bird_code_to_name = {
  'wbwwre1': 'White-breasted Wood-Wren',
  'houspa': 'House Sparrow',
  'redcro': 'Red Crossbill',  
  'chcant2': 'Chestnut-crowned Antpitta',
  'azaspi1': "Azara's Spinetail",   
}

birds_images = {
  'wbwwre1': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/22/Henicorhina_leucosticta_%28Cucarachero_pechiblanco%29_-_Juvenil_%2814037225664%29.jpg/640px-Henicorhina_leucosticta_%28Cucarachero_pechiblanco%29_-_Juvenil_%2814037225664%29.jpg', # 	Alejandro Bayer Tamayo from Armenia, Colombia 
  'houspa': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/52/House_Sparrow%2C_England_-_May_09.jpg/571px-House_Sparrow%2C_England_-_May_09.jpg', # 	Diliff
  'redcro': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Red_Crossbills_%28Male%29.jpg/640px-Red_Crossbills_%28Male%29.jpg', #  Elaine R. Wilson, www.naturespicsonline.com
  'chcant2': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/67/Chestnut-crowned_antpitta_%2846933264335%29.jpg/640px-Chestnut-crowned_antpitta_%2846933264335%29.jpg', # 	Mike's Birds from Riverside, CA, US
  'azaspi1': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b2/Synallaxis_azarae_76608368.jpg/640px-Synallaxis_azarae_76608368.jpg', # https://www.inaturalist.org/photos/76608368
}

test_files = os.path.abspath(os.path.join(data_dir, 'test/*/*.wav'))
def get_random_audio_file():
  test_list = glob.glob(test_files)
  random_audio_path = random.choice(test_list)
  return random_audio_path


def show_bird_data(audio_path):
  sample_rate, audio_data = wavfile.read(audio_path, 'rb')

  bird_code = audio_path.split('/')[-2]
  print(f'Bird name: {bird_code_to_name[bird_code]}')
  print(f'Bird code: {bird_code}')
  display(Image(birds_images[bird_code]))

  plttitle = f'{bird_code_to_name[bird_code]} ({bird_code})'
  plt.title(plttitle)
  plt.plot(audio_data)
  display(Audio(audio_data, rate=sample_rate))

print('functions and data structures created')

random_audio = get_random_audio_file()
show_bird_data(random_audio)

spec = audio_classifier.YamNetSpec(
    keep_yamnet_and_custom_heads=True,
    frame_step=3 * audio_classifier.YamNetSpec.EXPECTED_WAVEFORM_LENGTH,
    frame_length=6 * audio_classifier.YamNetSpec.EXPECTED_WAVEFORM_LENGTH)




train_data = audio_classifier.DataLoader.from_folder(
    spec, os.path.join(data_dir, 'train'), cache=True)
train_data, validation_data = train_data.split(0.8)
test_data = audio_classifier.DataLoader.from_folder(
    spec, os.path.join(data_dir, 'test'), cache=True)


batch_size = 128
epochs = 100

print('Training the model')
model = audio_classifier.create(
    train_data,
    spec,
    validation_data,
    batch_size=batch_size,
    epochs=epochs)

print('Evaluating the model')
model.evaluate(test_data)

def show_confusion_matrix(confusion, test_labels):
  """Compute confusion matrix and normalize."""
  confusion_normalized = confusion.astype("float") / confusion.sum(axis=1)
  axis_labels = test_labels
  ax = sns.heatmap(
      confusion_normalized, xticklabels=axis_labels, yticklabels=axis_labels,
      cmap='Blues', annot=True, fmt='.2f', square=True)
  plt.title("Confusion matrix")
  plt.ylabel("True label")
  plt.xlabel("Predicted label")

confusion_matrix = model.confusion_matrix(test_data)
show_confusion_matrix(confusion_matrix.numpy(), test_data.index_to_label)


serving_model = model.create_serving_model()

print(f'Model\'s input shape and type: {serving_model.inputs}')
print(f'Model\'s output shape and type: {serving_model.outputs}')


random_audio = get_random_audio_file()
show_bird_data(random_audio)


sample_rate, audio_data = wavfile.read(random_audio, 'rb')

audio_data = np.array(audio_data) / tf.int16.max
input_size = serving_model.input_shape[1]

splitted_audio_data = tf.signal.frame(audio_data, input_size, input_size, pad_end=True, pad_value=0)

print(f'Test audio path: {random_audio}')
print(f'Original size of the audio data: {len(audio_data)}')
print(f'Number of windows for inference: {len(splitted_audio_data)}')

print(random_audio)

results = []
print('Result of the window ith:  your model class -> score,  (spec class -> score)')
for i, data in enumerate(splitted_audio_data):
  yamnet_output, inference = serving_model(data)
  results.append(inference[0].numpy())
  result_index = tf.argmax(inference[0])
  spec_result_index = tf.argmax(yamnet_output[0])
  t = spec._yamnet_labels()[spec_result_index]
  result_str = f'Result of the window {i}: ' \
  f'\t{test_data.index_to_label[result_index]} -> {inference[0][result_index].numpy():.3f}, ' \
  f'\t({spec._yamnet_labels()[spec_result_index]} -> {yamnet_output[0][spec_result_index]:.3f})'
  print(result_str)


results_np = np.array(results)
mean_results = results_np.mean(axis=0)
result_index = mean_results.argmax()
print(f'Mean result: {test_data.index_to_label[result_index]} -> {mean_results[result_index]}')


models_path = './birds_models'
print(f'Exporing the TFLite model to {models_path}')
# Out:
# TensorFlow Version: 2.7.4
# Model Maker Version: 0.3.4
# Downloading data from https://storage.googleapis.com/laurencemoroney-blog.appspot.com/birds_dataset.zip
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\data_utils.py:276, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     275 try:
# --> 276   urlretrieve(origin, fpath, dl_progress)
#     277 except urllib.error.HTTPError as e:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\data_utils.py:82, in urlretrieve(url, filename, reporthook, data)
#      80       break
# ---> 82 response = urlopen(url, data)
#      83 with open(filename, 'wb') as fd:
#
# File C:\HI_Course\python_file\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File C:\HI_Course\python_file\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File C:\HI_Course\python_file\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File C:\HI_Course\python_file\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     560 args = (dict, 'default', 'http_error_default') + orig_args
# --> 561 return self._call_chain(*args)
#
# File C:\HI_Course\python_file\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     493 func = getattr(handler, meth_name)
# --> 494 result = func(*args)
#     495 if result is not None:
#
# File C:\HI_Course\python_file\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 20
#      17 print(f"TensorFlow Version: {tf.__version__}")
#      18 print(f"Model Maker Version: {mm.__version__}")
# ---> 20 birds_dataset_folder = tf.keras.utils.get_file('birds_dataset.zip',
#      21                                                 'https://storage.googleapis.com/laurencemoroney-blog.appspot.com/birds_dataset.zip',
#      22                                                 cache_dir='./',
#      23                                                 cache_subdir='dataset',
#      24                                                 extract=True)
#      27 # @title [Run this] Util functions and data structures.
#      29 data_dir = './dataset/small_birds_dataset'
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\data_utils.py:278, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     276   urlretrieve(origin, fpath, dl_progress)
#     277 except urllib.error.HTTPError as e:
# --> 278   raise Exception(error_msg.format(origin, e.code, e.msg))
#     279 except urllib.error.URLError as e:
#     280   raise Exception(error_msg.format(origin, e.errno, e.reason))
#
# Exception: URL fetch failure on https://storage.googleapis.com/laurencemoroney-blog.appspot.com/birds_dataset.zip: 404 -- Not Found
